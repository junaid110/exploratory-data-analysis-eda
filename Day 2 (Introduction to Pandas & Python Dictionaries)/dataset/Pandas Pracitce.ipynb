# %%
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 32, 28, 22, 30],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami'],
    'Occupation': ['Engineer', 'Artist', 'Doctor', 'Student', 'Manager']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age         City Occupation
# 0    Alice   25     New York   Engineer
# 1      Bob   32  Los Angeles     Artist
# 2  Charlie   28      Chicago     Doctor
# 3    David   22      Houston    Student
# 4      Eve   30        Miami    Manager

# %%
df.index = ['AL','BO','CH','DA','EV']

# %%
df
# Out:
#        Name  Age         City Occupation
# AL    Alice   25     New York   Engineer
# BO      Bob   32  Los Angeles     Artist
# CH  Charlie   28      Chicago     Doctor
# DA    David   22      Houston    Student
# EV      Eve   30        Miami    Manager

# %%
bricks_csv = pd.read_csv("./dataset/bricks.csv")

# %%
bricks_csv
# Out:
#   Unnamed: 0       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %%
bricks_csv = pd.read_csv('./dataset/bricks.csv',index_col = 0)

# %%
bricks_csv
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
country = bricks_csv['country']

# %%
country
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object

# %%
type(country)
# Out:
# pandas.core.series.Series

# %%
country =bricks_csv[['country']]  #2d

# %%
type(country)
# Out:
# pandas.core.frame.DataFrame

# %%
bricks_csv[['country','capital']]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
bricks_csv[0:2]
# Out:
#    country   capital    area  population
# BR  Brazil  Brasilia   8.516       200.4
# RU  Russia    Moscow  17.100       143.5

# %%
bricks_csv[1:4]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
bricks_csv[:5]
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
bricks_csv.index
# Out:
# Index(['BR', 'RU', 'IN', 'CH', 'SA'], dtype='object')

# %% [markdown]
# ![image.png](attachment:c3595b8c-210c-4d28-bd34-fb9e49b9d425.png)

# %%
bricks_csv.loc[['RU']]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
print(type(bricks_csv.loc[['RU']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
bricks_csv.loc[['IN']]
# Out:
#    country    capital   area  population
# IN   India  New Delhi  3.286      1252.0

# %%
bricks_csv.loc[['IN','RU'],['capital','area']]
# Out:
#       capital    area
# IN  New Delhi   3.286
# RU     Moscow  17.100

# %%
bricks_csv.loc['RU':'CH']
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
bricks_csv.loc[:,['country','capital']]    #All Rows with Specific Columns
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
#.iloc

# %%
bricks_csv
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
bricks_csv.iloc[[1]]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
bricks_csv.iloc[[1,3,4]]
# Out:
#          country   capital    area  population
# RU        Russia    Moscow  17.100      143.50
# CH         China   Beijing   9.597     1357.00
# SA  South Africa  Pretoria   1.221       52.98

# %%
bricks_csv.iloc[[1,2,4],[0,3]]
# Out:
#          country  population
# RU        Russia      143.50
# IN         India     1252.00
# SA  South Africa       52.98

# %%
bricks_csv.iloc[:,[0,3]]
# Out:
#          country  population
# BR        Brazil      200.40
# RU        Russia      143.50
# IN         India     1252.00
# CH         China     1357.00
# SA  South Africa       52.98
